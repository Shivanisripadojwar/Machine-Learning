# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train=pd.read_csv(r"C:\Users\DELL\OneDrive\Desktop\MyWork\Machine Learning\datasets\train.csv")
df_test=pd.read_csv(r"C:\Users\DELL\OneDrive\Desktop\MyWork\Machine Learning\datasets\test.csv")

# %%
df_train
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %%
df_test
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
x_train = df_train['x']
y_train = df_train['y']
x_test = df_test['x']
y_test = df_test['y']

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

# %%
x_train = x_train.reshape(-1,1)
x_test = x_test.reshape(-1,1)

# %%
x_train ,x_test
# Out:
# (array([[2.40000000e+01],
#         [5.00000000e+01],
#         [1.50000000e+01],
#         [3.80000000e+01],
#         [8.70000000e+01],
#         [3.60000000e+01],
#         [1.20000000e+01],
#         [8.10000000e+01],
#         [2.50000000e+01],
#         [5.00000000e+00],
#         [1.60000000e+01],
#         [1.60000000e+01],
#         [2.40000000e+01],
#         [3.90000000e+01],
#         [5.40000000e+01],
#         [6.00000000e+01],
#         [2.60000000e+01],
#         [7.30000000e+01],
#         [2.90000000e+01],
#         [3.10000000e+01],
#         [6.80000000e+01],
#         [8.70000000e+01],
#         [5.80000000e+01],
#         [5.40000000e+01],
#         [8.40000000e+01],
#         [5.80000000e+01],
#         [4.90000000e+01],
#         [2.00000000e+01],
#         [9.00000000e+01],
#         [4.80000000e+01],
#         [4.00000000e+00],
#         [2.50000000e+01],
#         [4.20000000e+01],
#         [0.00000000e+00],
#         [6.00000000e+01],
# ...

# %%
x_train = x_train.reshape(-1,1)

# %%
x_train
# Out:
# array([[2.40000000e+01],
#        [5.00000000e+01],
#        [1.50000000e+01],
#        [3.80000000e+01],
#        [8.70000000e+01],
#        [3.60000000e+01],
#        [1.20000000e+01],
#        [8.10000000e+01],
#        [2.50000000e+01],
#        [5.00000000e+00],
#        [1.60000000e+01],
#        [1.60000000e+01],
#        [2.40000000e+01],
#        [3.90000000e+01],
#        [5.40000000e+01],
#        [6.00000000e+01],
#        [2.60000000e+01],
#        [7.30000000e+01],
#        [2.90000000e+01],
#        [3.10000000e+01],
#        [6.80000000e+01],
#        [8.70000000e+01],
#        [5.80000000e+01],
#        [5.40000000e+01],
#        [8.40000000e+01],
#        [5.80000000e+01],
#        [4.90000000e+01],
#        [2.00000000e+01],
#        [9.00000000e+01],
#        [4.80000000e+01],
#        [4.00000000e+00],
#        [2.50000000e+01],
#        [4.20000000e+01],
#        [0.00000000e+00],
#        [6.00000000e+01],
#        [9.30000000e+01],
#        [3.90000000e+01],
# ...

# %%
df_train.isnull().sum()
# Out:
# x    0
# y    1
# dtype: int64

# %%
# convert y_train to series first then apply mean
y_train1=pd.Series(y_train)

# %%
y_train1=y_train1.fillna(y_train1.mean())

# %%
y_train1.isnull().sum()
# Out:
# 0

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
clf=LinearRegression()

# %%
clf.fit(x_train,y_train1)
# Out:
# LinearRegression()

# %%
y_pred=clf.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.08551543941508621
